# %% [markdown]
# ## Phase 2: Distributed Training using Kubeflow Training Operator and SDK
#
# - **kubeflow-training SDK**: PyTorchJob creation and management
# - **TRL + PEFT**: Modern fine-tuning with LoRA adapters
# - **Distributed Training**: Multi-node GPU coordination

# %% [markdown]
# ### Training Configuration using kubeflow-training SDK

# %%
# %load_ext yamlmagic

# %%
# %%yaml training_parameters
#
# # Model configuration
# model_name_or_path: ibm-granite/granite-3.1-2b-instruct
# model_revision: main
# torch_dtype: bfloat16
# attn_implementation: flash_attention_2
# use_liger: false
#
# # PEFT / LoRA configuration
# use_peft: true
# lora_r: 16
# lora_alpha: 16  # Changed from 8 to 16 for better scaling
# lora_dropout: 0.05
# lora_target_modules: ["q_proj", "v_proj", "k_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]
# lora_modules_to_save: []
#
# # QLoRA (BitsAndBytes)
# load_in_4bit: false
# load_in_8bit: false
#
# # Dataset configuration (synthetic data from Ray preprocessing)
# dataset_path: synthetic_gsm8k
# dataset_config: main
# dataset_train_split: train
# dataset_test_split: test
# dataset_text_field: text
# dataset_kwargs:
#   add_special_tokens: false
#   append_concat_token: false
#
# # SFT configuration  # Fixed typo
# max_seq_length: 1024
# dataset_batch_size: 1000
# packing: false
#
# # Training hyperparameters
# num_train_epochs: 3
# per_device_train_batch_size: 8
# per_device_eval_batch_size: 8
# auto_find_batch_size: false
# eval_strategy: epoch
#
# # Precision and optimization
# bf16: true
# tf32: false
# learning_rate: 1.0e-4  # Reduced from 2.0e-4 for more stable LoRA training
# warmup_steps: 100      # Increased from 10 for better stability
# lr_scheduler_type: inverse_sqrt
# optim: adamw_torch_fused
# max_grad_norm: 1.0
# seed: 42
#
# # Gradient settings
# gradient_accumulation_steps: 1
# gradient_checkpointing: false
# gradient_checkpointing_kwargs:
#   use_reentrant: false
#
# # FSDP for distributed training
# fsdp: "full_shard auto_wrap"
# fsdp_config:
#   activation_checkpointing: true
#   cpu_ram_efficient_loading: false
#   sync_module_states: true
#   use_orig_params: true
#   limit_all_gathers: false
#
# # Checkpointing and logging
# save_strategy: epoch
# save_total_limit: 1
# resume_from_checkpoint: false
# log_level: warning
# logging_strategy: steps
# logging_steps: 10      # Reduced frequency from 1 to 10
# report_to:
# - tensorboard
#
# output_dir: /shared/models/granite-3.1-2b-instruct-synthetic

# %% [markdown]
# ### Configure kubeflow-training Client
#
# Set up the kubeflow-training SDK client following the sft.ipynb pattern:

# %%
# Configure kubeflow-training client (following sft.ipynb pattern)
from kubernetes import client
from kubeflow.training import TrainingClient
from kubeflow.training.models import V1Volume, V1VolumeMount, V1PersistentVolumeClaimVolumeSource

token="<auth-token>"
api_server="<api-server-url>"

configuration = client.Configuration()
configuration.host = api_server
configuration.api_key = {"authorization": f"Bearer {token}"}
# Un-comment if your cluster API server uses a self-signed certificate or an un-trusted CA
configuration.verify_ssl = False

api_client = client.ApiClient(configuration)
training_client = TrainingClient(client_configuration=api_client.configuration)

print("kubeflow-training client configured")
# Out:
# kubeflow-training client configured

# %%
from kft_granite_training import training_func

job = training_client.create_job(
    job_kind="PyTorchJob",
    name="test1-training",
    # Use script file instead of function import
    train_func=training_func,
    # Pass YAML parameters as config
    parameters=training_parameters,
    # Distributed training configuration
    num_workers=2,
    num_procs_per_worker=1,
    resources_per_worker={
        "nvidia.com/gpu": 1,  # Uncomment for GPU training
        "memory": "16Gi",
        "cpu": 4,
    },
    base_image="quay.io/modh/training:py311-cuda124-torch251",
    # Environment variables for training
    
    env_vars={
        # HuggingFace configuration - use shared storage
        "HF_HOME": "/shared/huggingface_cache",
        "HF_DATASETS_CACHE": "/shared/huggingface_cache/datasets",
        "TOKENIZERS_PARALLELISM": "false",
        # Training configuration
        "PYTHONUNBUFFERED": "1",
        "NCCL_DEBUG": "INFO",
    },
    # Package dependencies
    packages_to_install=[
        "transformers>=4.36.0",
        "trl>=0.7.0",
        "datasets>=2.14.0",
        "peft>=0.6.0",
        "accelerate>=0.24.0",
        "torch>=2.0.0",
    ],
    volumes=[
        V1Volume(
            name="shared",
            persistent_volume_claim=V1PersistentVolumeClaimVolumeSource(claim_name="shared")
        ),
    ],
    volume_mounts=[
        V1VolumeMount(name="shared", mount_path="/shared"),
    ],
)

print(f"PyTorchJob submitted successfully")
# Out:
# PyTorchJob submitted successfully

# %% [markdown]
# ### Create Training Job using kubeflow-training SDK
#
# Create and submit the distributed training job following the sft.ipynb pattern:

# %% [markdown]
# ### Monitor Training Job
#
# Follow the training progress and logs:

# %%
# Monitor training job logs (following sft.ipynb pattern)
training_client.get_job_logs(
    name="test1-training",
    job_kind="PyTorchJob",
    follow=True,
)
# Out:
# [Pod test1-training-master-0]: [2025-09-26 15:10:52,898] [INFO] [real_accelerator.py:239:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [Pod test1-training-master-0]: df: /opt/app-root/src/.triton/autotune: No such file or directory
# [Pod test1-training-master-0]: Starting Granite fine-tuning on synthetic data...
# [Pod test1-training-master-0]: HuggingFace cache directory: /shared/huggingface_cache
# [Pod test1-training-master-0]: Output directory: /shared/models/granite-3.1-2b-instruct-synthetic
# [Pod test1-training-master-0]: Using device: cuda
# [Pod test1-training-master-0]: Model not found in shared PVC, will download from HuggingFace Hub: ibm-granite/granite-3.1-2b-instruct
# [Pod test1-training-master-0]: Downloaded model will be cached in: /shared/huggingface_cache
# [Pod test1-training-master-0]: Loading synthetic dataset...
# [Pod test1-training-master-0]: Loaded synthetic dataset from: /shared/synthetic_data/synthetic_dataset.json
# [Pod test1-training-master-0]: Converted list format: 24 train, 7 test samples
# Map: 100%|██████████| 24/24 [00:00<00:00, 2013.23 examples/s]
# Map: 100%|██████████| 7/7 [00:00<00:00, 3139.45 examples/s]
# [Pod test1-training-master-0]: Dataset prepared: 24 train samples
# [Pod test1-training-master-0]: Sample 20:
# [Pod test1-training-master-0]: <|start_of_role|>system<|end_of_role|>Knowledge Cutoff Date: April 2024.
# [Pod test1-training-master-0]: Today's Date: September 26, 2025.
# [Pod test1-training-master-0]: You are Granite, developed by IBM. You are a helpful AI assistant.<|end_of_text|>
# [Pod test1-training-master-0]: <|start_of_role|>user<|end_of_role|>Mrs. Johnson's class collected 750 cans for their recycling drive. She divided them equally among her 9 students. How many cans did each student receive?<|end_of_text|>
# [Pod test1-training-master-0]: <|start_of_role|>assistant<|end_of_role|>Each student received 85 cans because 750 ÷ 9 = <<750÷9=85>>85<|end_of_text|>
# [Pod test1-training-master-0]:
# [Pod test1-training-master-0]: --------------------------------------------------
# [Pod test1-training-master-0]: Sample 3:
# [Pod test1-training-master-0]: <|start_of_role|>system<|end_of_role|>Knowledge Cutoff Date: April 2024.
# [Pod test1-training-master-0]: Today's Date: September 26, 2025.
# [Pod test1-training-master-0]: You are Granite, developed by IBM. You are a helpful AI assistant.<|end_of_text|>
# [Pod test1-training-master-0]: <|start_of_role|>user<|end_of_role|>A store sells apples at $0.50 each. If you have $10 to spend, how many apples can you buy?<|end_of_text|>
# [Pod test1-training-master-0]: <|start_of_role|>assistant<|end_of_role|>If you have $10 and each apple costs $0.50, you can buy 10 / 0.50 = <<10/0.5=20>>20 apples.<|end_of_text|>
# [Pod test1-training-master-0]:
# [Pod test1-training-master-0]: --------------------------------------------------
# [Pod test1-training-master-0]: [rank0]:[W926 15:11:04.788811992 ProcessGroupNCCL.cpp:4115] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect.Specify device_ids in barrier() to force use of a particular device,or call init_process_group() with a device_id.
# [Pod test1-training-master-0]: test1-training-master-0:75:75 [0] NCCL INFO Bootstrap : Using eth0:10.131.4.141<0>
# [Pod test1-training-master-0]: test1-training-master-0:75:75 [0] NCCL INFO NET/Plugin: No plugin found (libnccl-net.so)
# [Pod test1-training-master-0]: test1-training-master-0:75:75 [0] NCCL INFO NET/Plugin: Plugin load returned 2 : libnccl-net.so: cannot open shared object file: No such file or directory : when loading libnccl-net.so
# [Pod test1-training-master-0]: test1-training-master-0:75:75 [0] NCCL INFO NET/Plugin: Using internal network plugin.
# [Pod test1-training-master-0]: test1-training-master-0:75:75 [0] NCCL INFO cudaDriverVersion 13000
# [Pod test1-training-master-0]: NCCL version 2.21.5+cuda12.4
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO NET/IB : No device found.
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO NET/Socket : Using [0]eth0:10.131.4.141<0>
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Using non-device net plugin version 0
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Using network Socket
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO ncclCommInitRank comm 0x5624878403e0 rank 0 nranks 2 cudaDev 0 nvmlDev 0 busId 8020 commId 0xcba6c6240f24aed6 - Init START
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Setting affinity for GPU 0 to ff,ffffffff
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO comm 0x5624878403e0 rank 0 nRanks 2 nNodes 2 localRanks 1 localRank 0 MNNVL 0
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Channel 00/02 :    0   1
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Channel 01/02 :    0   1
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Trees [0] 1/-1/-1->0->-1 [1] -1/-1/-1->0->1
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO P2P Chunksize set to 131072
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Channel 00/0 : 1[0] -> 0[0] [receive] via NET/Socket/0
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Channel 01/0 : 1[0] -> 0[0] [receive] via NET/Socket/0
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Channel 00/0 : 0[0] -> 1[0] [send] via NET/Socket/0
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Channel 01/0 : 0[0] -> 1[0] [send] via NET/Socket/0
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Connected all rings
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO Connected all trees
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO threadThresholds 8/8/64 | 16/8/64 | 512 | 512
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO 2 coll channels, 2 collnet channels, 0 nvls channels, 2 p2p channels, 2 p2p channels per peer
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO TUNER/Plugin: Plugin load returned 2 : libnccl-net.so: cannot open shared object file: No such file or directory : when loading libnccl-tuner.so
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO TUNER/Plugin: Using internal tuner plugin.
# [Pod test1-training-master-0]: test1-training-master-0:75:305 [0] NCCL INFO ncclCommInitRank comm 0x5624878403e0 rank 0 nranks 2 cudaDev 0 nvmlDev 0 busId 8020 commId 0xcba6c6240f24aed6 - Init COMPLETE
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# [Pod test1-training-master-0]: Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Fetching 2 files: 100%|██████████| 2/2 [02:32<00:00, 76.38s/it]
# [Pod test1-training-master-0]: You are attempting to use Flash Attention 2.0 with a model not initialized on GPU. Make sure to move the model to GPU after initializing it on CPU with `model.to('cuda')`.
# Loading checkpoint shards: 100%|██████████| 2/2 [00:00<00:00,  3.26it/s]
# Converting train dataset to ChatML: 100%|██████████| 24/24 [00:00<00:00, 9123.84 examples/s]
# Adding EOS to train dataset: 100%|██████████| 24/24 [00:00<00:00, 11267.44 examples/s]
# Tokenizing train dataset: 100%|██████████| 24/24 [00:00<00:00, 1756.99 examples/s]
# Truncating train dataset: 100%|██████████| 24/24 [00:00<00:00, 14082.72 examples/s]
# Converting eval dataset to ChatML: 100%|██████████| 7/7 [00:00<00:00, 4413.07 examples/s]
# Adding EOS to eval dataset: 100%|██████████| 7/7 [00:00<00:00, 4904.80 examples/s]
# Tokenizing eval dataset: 100%|██████████| 7/7 [00:00<00:00, 1412.50 examples/s]
# Truncating eval dataset: 100%|██████████| 7/7 [00:00<00:00, 4612.02 examples/s]
# [Pod test1-training-master-0]: No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# [Pod test1-training-master-0]: trainable params: 28,180,480 || all params: 2,561,712,128 || trainable%: 1.1001
# [Pod test1-training-master-0]: Starting training...
#  33%|███▎      | 2/6 [00:08<00:16,  4.24s/it]
#
# {'eval_loss': 2.8643341064453125, 'eval_runtime': 1.4526, 'eval_samples_per_second': 4.819, 'eval_steps_per_second': 0.688, 'eval_num_tokens': 6013.0, 'eval_mean_token_accuracy': 0.6551607251167297, 'epoch': 1.0}
#  33%|███▎      | 2/6 [00:10<00:16,  4.24s/it]
# 100%|██████████| 1/1 [00:00<00:00, 158.33it/s]
#                                               /opt/app-root/lib64/python3.11/site-packages/torch/distributed/fsdp/fully_sharded_data_parallel.py:690: FutureWarning: FSDP.state_dict_type() and FSDP.set_state_dict_type() are being deprecated. Please use APIs, get_state_dict() and set_state_dict(), which can support different parallelisms, FSDP1, FSDP2, DDP. API doc: https://pytorch.org/docs/stable/distributed.checkpoint.html#torch.distributed.checkpoint.state_dict.get_state_dict .Tutorial: https://pytorch.org/tutorials/recipes/distributed_checkpoint_recipe.html .
# [Pod test1-training-master-0]:   warnings.warn(
#  67%|██████▋   | 4/6 [00:41<00:22, 11.02s/it]
#
# {'eval_loss': 2.860490322113037, 'eval_runtime': 1.4114, 'eval_samples_per_second': 4.96, 'eval_steps_per_second': 0.709, 'eval_num_tokens': 12303.0, 'eval_mean_token_accuracy': 0.6558375358581543, 'epoch': 2.0}
#  67%|██████▋   | 4/6 [00:43<00:22, 11.02s/it]
# 100%|██████████| 1/1 [00:00<00:00, 160.24it/s]
#                                               /opt/app-root/lib64/python3.11/site-packages/torch/distributed/fsdp/fully_sharded_data_parallel.py:690: FutureWarning: FSDP.state_dict_type() and FSDP.set_state_dict_type() are being deprecated. Please use APIs, get_state_dict() and set_state_dict(), which can support different parallelisms, FSDP1, FSDP2, DDP. API doc: https://pytorch.org/docs/stable/distributed.checkpoint.html#torch.distributed.checkpoint.state_dict.get_state_dict .Tutorial: https://pytorch.org/tutorials/recipes/distributed_checkpoint_recipe.html .
# [Pod test1-training-master-0]:   warnings.warn(
# 100%|██████████| 6/6 [01:16<00:00, 13.21s/it]
#
# {'eval_loss': 2.864776372909546, 'eval_runtime': 1.4325, 'eval_samples_per_second': 4.886, 'eval_steps_per_second': 0.698, 'eval_num_tokens': 18474.0, 'eval_mean_token_accuracy': 0.6548223495483398, 'epoch': 3.0}
# 100%|██████████| 6/6 [01:17<00:00, 13.21s/it]
# 100%|██████████| 1/1 [00:00<00:00, 168.85it/s]
#                                               /opt/app-root/lib64/python3.11/site-packages/torch/distributed/fsdp/fully_sharded_data_parallel.py:690: FutureWarning: FSDP.state_dict_type() and FSDP.set_state_dict_type() are being deprecated. Please use APIs, get_state_dict() and set_state_dict(), which can support different parallelisms, FSDP1, FSDP2, DDP. API doc: https://pytorch.org/docs/stable/distributed.checkpoint.html#torch.distributed.checkpoint.state_dict.get_state_dict .Tutorial: https://pytorch.org/tutorials/recipes/distributed_checkpoint_recipe.html .
# [Pod test1-training-master-0]:   warnings.warn(
# [Pod test1-training-master-0]: {'train_runtime': 100.989, 'train_samples_per_second': 0.713, 'train_steps_per_second': 0.059, 'train_loss': 2.7846689224243164, 'num_tokens': 18474.0, 'mean_token_accuracy': 0.6503091553846995, 'epoch': 3.0}
# 100%|██████████| 6/6 [01:40<00:00, 16.83s/it]
# [Pod test1-training-master-0]: /opt/app-root/lib64/python3.11/site-packages/torch/distributed/fsdp/fully_sharded_data_parallel.py:690: FutureWarning: FSDP.state_dict_type() and FSDP.set_state_dict_type() are being deprecated. Please use APIs, get_state_dict() and set_state_dict(), which can support different parallelisms, FSDP1, FSDP2, DDP. API doc: https://pytorch.org/docs/stable/distributed.checkpoint.html#torch.distributed.checkpoint.state_dict.get_state_dict .Tutorial: https://pytorch.org/tutorials/recipes/distributed_checkpoint_recipe.html .
# [Pod test1-training-master-0]:   warnings.warn(
# [Pod test1-training-master-0]: Training completed successfully!
# [Pod test1-training-master-0]: Model checkpoint saved to: /shared/models/granite-3.1-2b-instruct-synthetic
# [Pod test1-training-master-0]: Training info:
# [Pod test1-training-master-0]:    - Model: ibm-granite/granite-3.1-2b-instruct
# [Pod test1-training-master-0]:    - Epochs: 3
# [Pod test1-training-master-0]:    - LoRA rank: 16
# [Pod test1-training-master-0]:    - Synthetic samples: 24
# [Pod test1-training-master-0]: [rank0]:[W926 15:15:58.259919771 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())
# [Pod test1-training-master-0]: test1-training-master-0:75:306 [0] NCCL INFO [Service thread] Connection closed by localRank 0
# [Pod test1-training-master-0]: test1-training-master-0:75:367 [0] NCCL INFO comm 0x5624878403e0 rank 0 nranks 2 cudaDev 0 busId 8020 - Abort COMPLETE
# ({'test1-training-master-0': "[2025-09-26 15:10:52,898] [INFO] [real_accelerator.py:239:get_accelerator] Setting ds_accelerator to cuda (auto detect)df: /opt/app-root/src/.triton/autotune: No such file or directoryStarting Granite fine-tuning on synthetic data...HuggingFace cache directory: /shared/huggingface_cacheOutput directory: /shared/models/granite-3.1-2b-instruct-syntheticUsing device: cudaModel not found in shared PVC, will download from HuggingFace Hub: ibm-granite/granite-3.1-2b-instructDownloaded model will be cached in: /shared/huggingface_cacheLoading synthetic dataset...Loaded synthetic dataset from: /shared/synthetic_data/synthetic_dataset.jsonConverted list format: 24 train, 7 test samples\rMap:   0%|          | 0/24 [00:00<?, ? examples/s]\rMap: 100%|██████████| 24/24 [00:00<00:00, 2013.23 examples/s]\rMap:   0%|          | 0/7 [00:00<?, ? examples/s]\rMap: 100%|██████████| 7/7 [00:00<00:00, 3139.45 examples/s]Dataset prepared: 24 train samplesSample 20:<|start_of_role|>system<|end_of_role|>Knowledge Cutoff Date: April 2024.Today's Date: September 26, 2025.You are Granite, developed by IBM. You are a helpful AI assistant.<|end_of_text|><|start_of_role|>user<|end_of_role|>Mrs. Johnson's class collected 750 cans for their recycling drive. She divided them equally among her 9 students. How many cans did each student receive?<|end_of_text|><|start_of_role|>assistant<|end_of_role|>Each student received 85 cans because 750 ÷ 9 = <<750÷9=85>>85<|end_of_text|>--------------------------------------------------Sample 3:<|start_of_role|>system<|end_of_role|>Knowledge Cutoff Date: April 2024.Today's Date: September 26, 2025.You are Granite, developed by IBM. You are a helpful AI assistant.<|end_of_text|><|start_of_role|>user<|end_of_role|>A store sells apples at $0.50 each. If you have $10 to spend, how many apples can you buy?<|end_of_text|><|start_of_role|>assistant<|end_of_role|>If you have $10 and each apple costs $0.50, you can buy 10 / 0.50 = <<10/0.5=20>>20 apples.<|end_of_text|>--------------------------------------------------[rank0]:[W926 15:11:04.788811992 ProcessGroupNCCL.cpp:4115] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect.Specify device_ids in barrier() to force use of a particular device,or call init_process_group() with a device_id.test1-training-master-0:75:75 [0] NCCL INFO Bootstrap : Using eth0:10.131.4.141<0>test1-training-master-0:75:75 [0] NCCL INFO NET/Plugin: No plugin found (libnccl-net.so)test1-training-master-0:75:75 [0] NCCL INFO NET/Plugin: Plugin load returned 2 : libnccl-net.so: cannot open shared object file: No such file or directory : when loading libnccl-net.sotest1-training-master-0:75:75 [0] NCCL INFO NET/Plugin: Using internal network plugin.test1-training-master-0:75:75 [0] NCCL INFO cudaDriverVersion 13000NCCL version 2.21.5+cuda12.4test1-training-master-0:75:305 [0] NCCL INFO NET/IB : No device found.test1-training-master-0:75:305 [0] NCCL INFO NET/Socket : Using [0]eth0:10.131.4.141<0>test1-training-master-0:75:305 [0] NCCL INFO Using non-device net plugin version 0test1-training-master-0:75:305 [0] NCCL INFO Using network Sockettest1-training-master-0:75:305 [0] NCCL INFO ncclCommInitRank comm 0x5624878403e0 rank 0 nranks 2 cudaDev 0 nvmlDev 0 busId 8020 commId 0xcba6c6240f24aed6 - Init STARTtest1-training-master-0:75:305 [0] NCCL INFO Setting affinity for GPU 0 to ff,fffffffftest1-training-master-0:75:305 [0] NCCL INFO comm 0x5624878403e0 rank 0 nRanks 2 nNodes 2 localRanks 1 localRank 0 MNNVL 0test1-training-master-0:75:305 [0] NCCL INFO Channel 00/02 :    0   1test1-training-master-0:75:305 [0] NCCL INFO Channel 01/02 :    0   1test1-training-master-0:75:305 [0] NCCL INFO Trees [0] 1/-1/-1->0->-1 [1] -1/-1/-1->0->1test1-training-master-0:75:305 [0] NCCL INFO P2P Chunksize set to 131072test1-training-master-0:75:305 [0] NCCL INFO Cha ...
#  {})

# %%
# Delete the Training Job
training_client.delete_job("test1-training")
print("PytorchJob deleted!")
# Out:
# PytorchJob deleted!
